# %% [markdown]
# # CSS

# %% [markdown]
# #  <span style="color: red;">기본문법</span>
# ### 셀렉터: css적용시킬 일종의 태그
# ![image.png](attachment:ace9dc03-77f1-4929-bd6f-7e853d949578.png)
# ### { } 안에 선언
# ### property: value; 꼴, ;로 각 속성 구분

# %% [markdown]
# # <span style="color: red;">html과 css연동</span>

# %% [markdown]
# ### 1. 링크스타일(따로 따로)
# ![image.png](attachment:b876fad1-6908-4d83-bd44-321f4111d1d9.png)

# %% [markdown]
# ### 2. 임베딩 스타일
# ### \<head> 안의 \<style> 안에
# ### h1, p { color: red; } 이렇게 복수 지정 가능/ ','로 구분
# ![image.png](attachment:d383dff4-3bd0-4fe2-9023-2e179f47014f.png)

# %% [markdown]
# ### 3. 인라인 스타일
# ### \<body>안의 각 태그에 속성 style사용
# ### \<tag style='property: value'> 형태
# ![image.png](attachment:a9951c71-93a8-4248-9666-1f96fbf0ed9e.png)

# %% [markdown]
# # <span style="color: red;"> SELECTOR </span>

# %% [markdown]
# # <span style="color: blue;"> 1.전체 셀렉터 ( * ) </span>
# ### * 로 HTML내 모든 요소 선택, HEAD도 포함
# ![image.png](attachment:836efdf1-3c8f-4b00-a8b6-4224fd1e5ef6.png)

# %% [markdown]
# # <span style="color: blue;">2.태그 셀렉터</span>
# ### 선택된 태그 전부에 적용
# ![image.png](attachment:0a45c091-4c4f-44b9-995f-e95400605d5e.png)

# %% [markdown]
# # <span style="color: blue;">3.ID 셀렉터</span>
# ### 태그안에 속성으로 ID='ID정보'지정하고  #ID 형태로 사용
# ### ID값은 중복 불가
# ![image.png](attachment:fdfb27ab-18fa-4fbb-b9ef-a1105410ff45.png)

# %% [markdown]
# # <span style="color: blue;">4.클래스 셀렉터</span>
# ### 태그안에 속성으로 CLASS='CLASS명' 지정하고 .CLASS 형태로 사용
# ### **ID와 달리 중복 가능!!! -> 재사용성 높음
# ![image.png](attachment:1d114589-5c24-45cc-996c-c51674f44d6a.png)
# ## 이때 div안의 모든 자식 태그들에 적용, but class보다 id가 더 우선순위여서
# ## p2에는 #p2가 적용

# %% [markdown]
# ## <span style="color: green;"> **class성질   </span>
# ### class값으로 여러 값들이 동시에 들어갈 수 있음
# ### 구분자 필요없이 공백으로 구분
# ![image.png](attachment:44da662c-6bb8-4fec-9475-9620af370d3e.png)

# %% [markdown]
# # <span style="color: blue;"> 5. 어트리뷰트 셀렉터(속성)   </span>
# ### selector[속성] 지정해서 적용
# ### 태그와 속성둘다 동시에 가진 개체에 적용
# ![image.png](attachment:2056ddd9-72b3-4f81-a8ca-99c8a68fa8f8.png)
# ### selector[속성='값']으로 더 세부적이게 가능
# ![image.png](attachment:bb8cba26-1b10-4aa8-afa8-953085cb86fa.png)

# %% [markdown]
# # <span style="color: blue;"> 6.복합 셀렉터   </span>

# %% [markdown]
# ## <span style="color: blue;">6.1후손 셀렉터</span>
# ### 후손은 자손포함 + 더 밑의 자식들
# ### selector1 selector2{~} 형태
# ![image.png](attachment:466e3c67-2efa-4f80-b97a-56b76eff71f4.png)

# %% [markdown]
# ## <span style="color: blue;">6.2자식 셀렉터</span>
# ### **only 자손만
# ### selector1 > selector2 {~} 형태
# ![image.png](attachment:6ba5c62d-a384-4380-ba78-768b06fa7526.png)

# %% [markdown]
# ## <span style="color: blue;">6.3인접 or 일반 형제 셀렉터</span>
# ![image.png](attachment:0c57e628-190d-4b70-8bb6-a7c5afc3c65b.png)

# %% [markdown]
# ## <span style="color: blue;"> 7.가상클래스 셀렉터  </span>
# ### 특정 상태가 돼야 적용(마우스가 올라와 있을때, 링크 방문전과 방문 후)
# ### selector:pseudo-class {property: value;} 형태  ':'이후 class function사용
# ![image.png](attachment:25b3bf4f-caaa-4104-ad48-f3d5d6ad1456.png)
# ### hover: 마우스가 올라와있을때
# ### focus: 클릭했을떄
# ### link: 방문전  vs   visited: 방문후
# ### checked, enabled, disabled
# ### first-child vs  last-child  vs nth-child(n)
# ## selector:not([속성=값]){~}   ->selector안에서 해당하지 않는애들만

# %% [markdown]
# ## <span style="color: blue;"> 8.가상 요소 셀렉터  </span>
# ### 요소안의 특정부분에 적용
# ### selector::pseudo-element {property:value;} '::'두개 사용
# ![image.png](attachment:e623d261-e53d-41ed-9eed-d44cf6d9dbdb.png)
